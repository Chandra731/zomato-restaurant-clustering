# %% [markdown]
# # **Project Name**    - Zomato_Restaurant_Clustering_Project

# %% [markdown]
# ##### **Project Type**    - EDA/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1**   - Chandra Sekhar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## **Overview**
#
# The primary objective of this project was to analyze and cluster restaurants listed on Zomato based on various features such as cost, ratings, reviews, and cuisines. By leveraging data visualization, sentiment analysis, and clustering algorithms, we aimed to uncover insights that can help improve customer satisfaction and optimize business strategies.
#
# ## **Data Understanding and Cleaning**
#
# We began by loading two datasets: restaurant metadata and reviews. The datasets were merged on the restaurant name to create a comprehensive dataset. Initial examination revealed missing values and duplicate entries, which were addressed through a series of preprocessing steps:
# - **Feature Engineering**: A binary feature 'Has_Collections' was created to indicate the presence of collections, and the original 'Collections' column was dropped.
# - **Missing Values**: Missing values in columns such as 'Timings' and 'Time' were filled using the mode of related columns, while others like 'Reviewer', 'Review', and 'Metadata' were filled with placeholder values.
# - **Data Type Conversions**: The 'Cost' column was converted to numeric after removing currency symbols, and datetime conversion was applied to the 'Time' column.
# - **Standardization**: Column names were standardized to lowercase with underscores.
#
# ## **Data Visualization**
#
# A variety of visualizations were created to explore the relationships between different variables:
# 1. **Heatmap**: Showed the relationship between cost, cuisines, and average ratings.
# 2. **Jointplot**: Visualized the distribution of cost vs. ratings using Kernel Density Estimation (KDE).
# 3. **Boxenplot**: Compared the impact of collections on ratings.
# 4. **Countplot**: Highlighted the most common cuisine types.
# 5. **Violin Plot**: Displayed the distribution and density of restaurant ratings.
# 6. **Donut Chart**: Represented the proportion of different restaurant cost categories.
# 7. **Swarmplot**: Showed the relationship between restaurant cost and customer ratings.
# 8. **Word Cloud**: Highlighted frequently mentioned words in reviews.
# 9. **Line Plot**: Illustrated the trend of customer reviews over time.
# 10. **Boxplot**: Visualized the spread and distribution of ratings across various cuisines.
# 11. **Histogram**: Showed the distribution of review lengths.
# 12. **Barplot**: Highlighted the most active reviewers.
# 13. **Correlation Heatmap**: Represented the relationships between numerical features.
# 14. **Pair Plot**: Visualized relationships between multiple numerical features.
# 15. **Sentiment Distribution Donut Chart**: Illustrated the proportions of different sentiments in reviews.
#
# ## **Textual Data Preprocessing**
#
# Textual data preprocessing involved several steps to prepare the reviews for analysis:
# - **Expanding Contractions**: Ensured consistency in text.
# - **Lower Casing**: Converted all text to lowercase.
# - **Removing Punctuations, URLs, and Digits**: Cleaned the text.
# - **Removing Stopwords and White Spaces**: Reduced noise in the text.
# - **Rephrasing Text**: Applied lemmatization to convert words to their base form.
# - **Tokenization**: Split the text into individual words.
# - **Text Vectorization**: Used Word2Vec to convert text into numerical features, capturing the context and meaning of words.
#
# ## **Sentiment Analysis**
#
# Sentiment analysis was performed using VADER to classify reviews into positive, negative, and neutral sentiments. The distribution of sentiments was visualized to understand overall customer sentiment towards the restaurants.
#
# ## **Clustering**
#
# Three clustering algorithms were applied:
# 1. **KMeans**: Identified clusters based on cost, rating, sentiment score, and reviews. The silhouette score was 0.26, indicating moderate clustering.
# 2. **DBSCAN**: Detected arbitrary-shaped clusters and outliers based on density. The silhouette score was -0.20, indicating poor clustering.
# 3. **Agglomerative Clustering**: A hierarchical clustering method that recursively merges data points into clusters. The silhouette score was 0.19, indicating weak clustering.
#
# ## **Key Insights**
#
# - **Cost vs. Rating**: Higher cost doesn't always guarantee better ratings; some expensive cuisines had low ratings.
# - **Cuisines**: North Indian and Chinese cuisines were the most popular, while certain mixed cuisines also showed high demand.
# - **Review Trends**: Review activity increased significantly over time, indicating rising customer engagement.
# - **Sentiments**: A majority of reviews were positive, suggesting high customer satisfaction. However, there were notable negative reviews that need attention.
#
# ## **Business Impact**
#
# - **Pricing and Menu Adjustments**: Optimize pricing strategies and menu offerings to enhance customer satisfaction.
# - **Marketing and Promotions**: Target highly rated and popular cuisines for promotions to attract more customers.
# - **Quality Improvement**: Address negative reviews and improve the quality of lower-rated restaurants to enhance overall customer experience.
#
# ## **Future Work**
#
# - **Model Deployment**: Deploy the final KMeans model for real-time clustering and analysis of new restaurant data.
# - **Enhanced Sentiment Analysis**: Incorporate more advanced NLP techniques and pretrained models to improve sentiment analysis accuracy.
# - **Additional Features**: Include more features such as location, ambiance, and service quality for deeper insights into customer preferences.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Link: https://github.com/Chandra731/zomato-restaurant-clustering

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
restaurant_data = pd.read_csv("/content/Zomato Restaurant names and Metadata.csv")
review_data = pd.read_csv("/content/Zomato Restaurant reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
restaurant_data.head()
# Out:
#                              Name  \
# 0                 Beyond Flavours
# 1                        Paradise
# 2                        Flechazo
# 3  Shah Ghouse Hotel & Restaurant
# 4      Over The Moon Brew Company
#
#                                                Links   Cost  \
# 0  https://www.zomato.com/hyderabad/beyond-flavou...    800
# 1  https://www.zomato.com/hyderabad/paradise-gach...    800
# 2  https://www.zomato.com/hyderabad/flechazo-gach...  1,300
# 3  https://www.zomato.com/hyderabad/shah-ghouse-h...    800
# 4  https://www.zomato.com/hyderabad/over-the-moon...  1,200
#
#                                          Collections  \
# 0  Food Hygiene Rated Restaurants in Hyderabad, C...
# 1                                Hyderabad's Hottest
# 2                 Great Buffets, Hyderabad's Hottest
# 3                             Late Night Restaurants
# 4  Best Bars & Pubs, Food Hygiene Rated Restauran...
#
#                                             Cuisines  \
# ...

# %%
review_data.head()
# Out:
#         Restaurant              Reviewer  \
# 0  Beyond Flavours     Rusha Chakraborty
# 1  Beyond Flavours  Anusha Tirumalaneedi
# 2  Beyond Flavours       Ashok Shekhawat
# 3  Beyond Flavours        Swapnil Sarkar
# 4  Beyond Flavours                Dileep
#
#                                               Review Rating  \
# 0  The ambience was good, food was quite good . h...      5
# 1  Ambience is too good for a pleasant evening. S...      5
# 2  A must try.. great food great ambience. Thnx f...      5
# 3  Soumen das and Arun was a great guy. Only beca...      5
# 4  Food is good.we ordered Kodi drumsticks and ba...      5
#
#                   Metadata             Time  Pictures
# 0   1 Review , 2 Followers  5/25/2019 15:54         0
# 1  3 Reviews , 2 Followers  5/25/2019 14:20         0
# 2  2 Reviews , 3 Followers  5/24/2019 22:54         0
# 3    1 Review , 1 Follower  5/24/2019 22:11         0
# 4  3 Reviews , 2 Followers  5/24/2019 21:37         0

# %%
# Rename Columns
restaurant_data.rename(columns={"Name": "Restaurant"}, inplace=True)

# %%
# Merge the Datasets
merged_data = pd.merge(restaurant_data, review_data, on="Restaurant", how="inner")

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
merged_data.shape
# Out:
# (10000, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Restaurant   10000 non-null  object
#  1   Links        10000 non-null  object
#  2   Cost         10000 non-null  object
#  3   Collections  5000 non-null   object
#  4   Cuisines     10000 non-null  object
#  5   Timings      9900 non-null   object
#  6   Reviewer     9962 non-null   object
#  7   Review       9955 non-null   object
#  8   Rating       9962 non-null   object
#  9   Metadata     9962 non-null   object
#  10  Time         9962 non-null   object
#  11  Pictures     10000 non-null  int64
# dtypes: int64(1), object(11)
# memory usage: 937.6+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
merged_data.duplicated().sum()
# Out:
# 36

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
merged_data.isna().sum()
# Out:
# Restaurant        0
# Links             0
# Cost              0
# Collections    5000
# Cuisines          0
# Timings         100
# Reviewer         38
# Review           45
# Rating           38
# Metadata         38
# Time             38
# Pictures          0
# dtype: int64

# %%
# Visualizing the missing values
import missingno as msno
msno.matrix(merged_data)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * Size: 10,000 rows × 12 columns
#
# Missing Values:
# * Collections (50% missing)
# * Timings (100), Reviewer (38), Review (45), Rating (38), Metadata (38), Time (38)
# * Duplicates: 36

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
merged_data.columns
# Out:
# Index(['Restaurant', 'Links', 'Cost', 'Collections', 'Cuisines', 'Timings',
#        'Reviewer', 'Review', 'Rating', 'Metadata', 'Time', 'Pictures'],
#       dtype='object')

# %%
# Dataset Describe
merged_data.describe()
# Out:
#            Pictures
# count  10000.000000
# mean       0.748600
# std        2.570381
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       64.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * Restaurant - Name of the restaurant
# Links	URL to the restaurant’s page
# * Cost -	Cost information (needs conversion if in string format)
# * Collections	- Grouping of restaurants (e.g., “Best Cafés”) – 50% missing values
# * Cuisines	- Types of cuisines offered (e.g., Indian, Chinese)
# * Timings -	Operating hours – 100 missing values
# * Reviewer	- Name of the reviewer – 38 missing values
# * Review -	Review text – 45 missing values
# * Rating -	Star rating given – 38 missing values
# * Metadata	- Additional details (e.g., review source) – 38 missing values
# * Time	- Timestamp of the review – 38 missing values
# * Pictures -	Number of images uploaded (numeric)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
merged_data.nunique()
# Out:
# Restaurant      100
# Links           100
# Cost             28
# Collections      42
# Cuisines         89
# Timings          74
# Reviewer       7446
# Review         9364
# Rating           10
# Metadata       2477
# Time           9782
# Pictures         36
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Feature Engineering: Handling Missing Values
merged_data["Has_Collections"] = merged_data["Collections"].notna().astype(int)
merged_data.drop("Collections", axis=1, inplace=True)

# Fill Missing Values
merged_data["Timings"] = merged_data.groupby("Cuisines")["Timings"].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else "Unknown")
)
merged_data["Time"] = merged_data.groupby("Restaurant")["Time"].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else pd.Timestamp.now())
)
merged_data["Reviewer"].fillna("Anonymous", inplace=True)
merged_data["Review"].fillna("No Review", inplace=True)
merged_data["Metadata"].fillna("No Data Available", inplace=True)
merged_data["Rating"] = pd.to_numeric(merged_data["Rating"], errors="coerce")
merged_data["Rating"].fillna(merged_data["Rating"].mean(), inplace=True)

# Convert "Cost" to Numeric
merged_data["Cost"] = merged_data["Cost"].replace("[₹,]", "", regex=True).astype(float)

# Standardize Column Names
merged_data.columns = merged_data.columns.str.lower().str.replace(" ", "_")

# Convert "Time" Column to Datetime
merged_data["time"] = pd.to_datetime(merged_data["time"], errors="coerce")

# Verify if There Are Any Missing Values Left
print(merged_data.isna().sum())
# Out:
# restaurant         0
# links              0
# cost               0
# cuisines           0
# timings            0
# reviewer           0
# review             0
# rating             0
# metadata           0
# time               0
# pictures           0
# has_collections    0
# dtype: int64
# <ipython-input-15-ffe446b88cbb>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_data["Reviewer"].fillna("Anonymous", inplace=True)
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations Done:
# Feature Engineering:
#
# * Created has_collections (binary feature) indicating whether Collections had a value.
# * Dropped Collections after encoding.
#
# Handling Missing Values:
#
# * Timings: Filled missing values based on the mode of Cuisines.
# * Time: Filled missing values based on the mode of Restaurant, or set to the current timestamp.
# * Reviewer, Review, Metadata: Replaced missing values with "Anonymous", "No Review", and "No Data Available", respectively.
# * Rating: Converted to numeric and filled missing values with the mean rating.
#
# Data Type Conversions & Cleaning:
#
# * Cost: Removed currency symbols and converted to float.
# * Column Names: Standardized to lowercase with underscores.
# * Time: Converted to datetime format.
#
# Insights Found:
# * Collections was missing in 50% of records, so it was converted into a binary feature.
# * Timings & Time showed consistency within the same Cuisines and Restaurant.
# * Rating had missing values, but replacing them with the mean ensured consistency.
# * Cost is now ready for numerical analysis after removing currency symbols.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 - Heatmap: Cost vs. Rating
plt.figure(figsize=(10, 8))
sns.heatmap(merged_data.pivot_table(index='cuisines', columns='cost', values='rating', aggfunc='mean'), cmap='coolwarm', annot=True)
plt.title("Average Ratings Across Different Cost and Cuisines")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap effectively visualizes the relationship between cost, cuisines, and average ratings using a color gradient for quick comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Higher cost doesn’t guarantee better ratings; some expensive cuisines have low ratings.
# * Certain cuisines (North Indian, Chinese, Continental) maintain consistent ratings, while others fluctuate.
# * Lower-cost options (₹200-₹800) receive high ratings, indicating strong value perception.
# * ₹1400, ₹1800, ₹2800 show lower ratings, suggesting poor value for money.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Helps optimize pricing, menu adjustments, and value offerings.
# * Negative: High-cost, low-rated items may lead to dissatisfaction and revenue loss if not addressed.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 - Jointplot: Cost vs. Rating with KDE
sns.jointplot(x='cost', y='rating', data=merged_data, kind="kde", fill=True, cmap='Blues')
plt.suptitle("Cost vs. Rating with Density Estimates", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Kernel Density Estimation (KDE) plot visualizes the distribution of cost vs. ratings, highlighting concentration areas for better insight into spending patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most high-rated restaurants fall within a cost range of ₹200-₹1000, indicating affordability drives better reviews.
# * Extreme price points (>₹2000) are less frequent, suggesting fewer high-cost establishments or lower demand.
# * Low ratings are also concentrated in the lower-cost range, meaning pricing alone doesn't determine customer satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Helps businesses optimize pricing strategies and target the most profitable customer segments.
# * Negative: If premium-priced restaurants fail to justify costs with quality, they risk lower customer retention.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 - Boxenplot: Impact of Collection on Ratings
plt.figure(figsize=(10, 8))
sns.boxenplot(x='has_collections', y='rating', data=merged_data, palette="coolwarm")
plt.xlabel("Has Collections (0 = No, 1 = Yes)")
plt.ylabel("Rating")
plt.title("Impact of Collections on Ratings")
plt.show()
# Out:
# <ipython-input-18-1796dfe584f3>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x='has_collections', y='rating', data=merged_data, palette="coolwarm")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot effectively compares the impact of collections on ratings, showing distribution, median, and variability between restaurants that are part of collections and those that are not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Restaurants with collections (1) tend to have higher ratings, as their median rating is higher than those without.
# * Establishments without collections (0) have a wider spread, including more low-rated restaurants.
# * Collections may influence customer perception, leading to better engagement and reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Encourages businesses to join curated collections to boost visibility and ratings.
# * Negative: Restaurants outside collections may struggle to attract customers, potentially impacting sales.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 - Countplot: Most Common Cuisine Types
plt.figure(figsize=(12, 8))
cuisine_counts = pd.Series(",".join(merged_data["cuisines"].dropna()).split(", ")).value_counts().head(10)
cuisine_counts_df = cuisine_counts.reset_index()
cuisine_counts_df.columns = ['Cuisine Type', 'Count']
sns.countplot(y='Cuisine Type', data=cuisine_counts_df, palette="viridis", order=cuisine_counts_df['Cuisine Type'])
plt.xlabel("Count")
plt.ylabel("Cuisine Type")
plt.title("Most Common Cuisine Types")
plt.show()
# Out:
# <ipython-input-19-7e3c64f5e2f7>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Cuisine Type', data=cuisine_counts_df, palette="viridis", order=cuisine_counts_df['Cuisine Type'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is great for comparing cuisine popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * North Indian cuisine is the most common, followed by Chinese, Continental, and Italian.
# * Mixed cuisines (e.g., "Chinese, North Indian" and "Biryani, North Indian") are also prevalent, indicating customer interest in variety.
# * Mughlai and Kebab also have a strong presence, suggesting high demand for traditional and flavorful dishes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Helps restaurants focus on popular cuisines and offer fusion options.
# * Negative: Niche cuisines may struggle and need strong marketing.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 - Violin Plot: Distribution of Ratings
plt.figure(figsize=(10, 8))
sns.violinplot(x='rating', data=merged_data, palette="pastel")
plt.xlabel("Ratings")
plt.ylabel("Density")
plt.title("Distribution of Restaurant Ratings")
plt.show()
# Out:
# <ipython-input-20-7e9a659f9c42>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='rating', data=merged_data, palette="pastel")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot shows both the distribution and density of restaurant ratings effectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Ratings are skewed towards higher values, with a peak near 5-star ratings.
# * Some restaurants have low ratings, but they are fewer in number.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * High ratings suggest customer satisfaction; marketing can highlight top-rated restaurants.
# * Negative: Poor-rated restaurants may need quality improvements to avoid customer loss.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 - Donut Chart: Restaurant Cost Distribution
merged_data["cost_category"] = pd.qcut(merged_data["cost"], q=3, labels=["Low", "Medium", "High"])
cost_counts = merged_data["cost_category"].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(
    cost_counts, labels=cost_counts.index, autopct="%1.1f%%", colors=["lightgreen", "orange", "red"], startangle=140,
    wedgeprops=dict(width=0.3)
)
plt.title("Restaurant Cost Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A donut chart clearly represents the proportion of different restaurant cost categories in a visually appealing way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Low-cost restaurants dominate (42%), followed by high-cost (31%) and medium-cost (27%).
# * A significant portion of restaurants are budget-friendly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Low-cost dominance indicates affordability, attracting more customers.
# * Negative: A lower share of medium-cost restaurants may indicate a pricing gap, leading

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 Swarmplot: Price Range vs. Ratings
plt.figure(figsize=(16, 8))
sns.stripplot(x="cost", y="rating", data=merged_data, palette="plasma", jitter=True)
plt.xlabel("Cost")
plt.ylabel("Rating")
plt.title("Price Range vs. Ratings Distribution")
plt.show()
# Out:
# <ipython-input-22-5e87ea00e1b7>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x="cost", y="rating", data=merged_data, palette="plasma", jitter=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen because it effectively shows the relationship between restaurant cost and customer ratings. The color gradient further helps visualize trends across different price points.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Higher-cost restaurants (above ₹1000) tend to have higher ratings (4.0 - 5.0).
# * Lower-cost restaurants (below ₹500) have mixed ratings, with many falling between 1.0 - 3.0.
# * Mid-range restaurants (₹500 - ₹1000) have a diverse spread, but ratings lean toward 3.0 - 4.5.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Premium restaurants justify their cost with high ratings, supporting pricing strategies.
# * Businesses can focus on maintaining quality in mid-range restaurants to improve ratings.
#
# Negative:
#
# * Many low-cost restaurants have poor ratings, which could drive customers away.
# * If higher-cost restaurants fail to maintain high ratings, customers may feel the price isn't justified.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 Word Cloud: Reviews
from wordcloud import WordCloud

text = " ".join(merged_data["review"].dropna().astype(str).tolist())
wordcloud = WordCloud(width=800, height=400, background_color="white", colormap="viridis").generate(text)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Restaurant Reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A word cloud was chosen because it visually highlights the most frequently mentioned words in restaurant reviews. Larger words indicate higher frequency, making it easy to identify key themes in customer feedback.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Positive: food, service, taste, ambiance, great, good, staff.
# * Popular items: biryani, chicken, pizza, starter, ice cream.
# * Service-related terms: ordered, time, staff, experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Helps focus on strengths (food, service, ambiance).
# * Optimizes menus based on popular items.
# * Potential issues like delays in service need further review.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 Line Plot: Number of Reviews Over Time
merged_data["review_date"] = merged_data["time"].dt.date
reviews_over_time = merged_data.groupby("review_date").size()
plt.figure(figsize=(12, 8))
reviews_over_time.plot(kind='line', color='blue')
plt.xlabel("Date")
plt.ylabel("Number of Reviews")
plt.title("Number of Reviews Over Time")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line Chart was chosen to visualize the trend of customer reviews over time, making it easier to observe growth patterns and anomalies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * 2016-2017: Low review activity.
# * Mid-2017 onward: Gradual increase in reviews.
# * Early 2018: Sharp spike, followed by consistent growth.
# * 2019: Sustained high review volume

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Increasing reviews indicate rising customer engagement and brand visibility.
# * Potential Concern: Sudden spikes could be due to promotions or negative incidents. Sentiment analysis can help clarify the cause.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 Boxplot: Rating Distribution by Cuisine
plt.figure(figsize=(12, 14))
sns.boxplot(x="rating", y="cuisines", data=merged_data, palette="Set2")
plt.xlabel("Rating")
plt.ylabel("Cuisine")
plt.title("Rating Distribution by Cuisine")
plt.show()
# Out:
# <ipython-input-25-3dc8ce6f473e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="rating", y="cuisines", data=merged_data, palette="Set2")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box Plot was chosen to visualize the spread and distribution of ratings across various cuisines, helping identify consistency and outliers in customer feedback.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some cuisines have consistently high ratings, while others show high variability with lower ratings.
# * Certain cuisines have a wider spread, indicating mixed customer experiences.
# * Outliers suggest exceptionally high or low-rated instances that may need further investigation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Identifying highly rated cuisines helps in promoting best-performing categories.
# * Negative: Cuisines with low ratings or high variability may need quality improvement efforts to enhance customer satisfaction.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 Histogram: Review Length Distribution
merged_data["review_length"] = merged_data["review"].apply(len)

plt.figure(figsize=(12, 8))
sns.histplot(merged_data["review_length"], bins=30, kde=True, color="orange")
plt.xlabel("Review Length (words)")
plt.ylabel("Count")
plt.title("Distribution of Review Lengths")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram with KDE (Kernel Density Estimation) was chosen to visualize the distribution of review lengths, helping understand how customers write reviews

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution is right-skewed, meaning most reviews are short, while very few are extremely long.
# * A significant number of reviews fall below 500 words, with very few exceeding 1000 words.
# * Long reviews are rare but may carry detailed feedback.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Short reviews suggest quick engagement, making it easier for new customers to scan ratings.
# * Negative: If most reviews are too short, important feedback might be missing, requiring strategies to encourage more detailed reviews.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 Barplot: Top 10 Reviewers by Number of Reviews
top_reviewers = merged_data["reviewer"].value_counts().head(10)
plt.figure(figsize=(12, 8))
sns.barplot(x=top_reviewers.index, y=top_reviewers.values, palette="Blues_d")
plt.xlabel("Reviewer")
plt.ylabel("Number of Reviews")
plt.title("Top 10 Reviewers by Number of Reviews")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-27-17e085cc5803>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_reviewers.index, y=top_reviewers.values, palette="Blues_d")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to highlight the most active reviewers by the number of reviews they have posted. This helps identify key contributors and trends in user engagement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The highest number of reviews come from Anonymous users, which means many users prefer not to disclose their identity.
# * Among named reviewers, Ankita and Parijat Ray are the most active, followed by others with a steady contribution.
# * The review count drops significantly after the top reviewer, suggesting a small group of highly engaged users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Identifying top contributors can help businesses engage them more (e.g., loyalty programs, exclusive offers).
# * Negative: A high number of anonymous reviews may indicate trust issues—customers might not want to associate their name with reviews. Implementing verified reviews or incentives for real users could improve credibility.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 Donut Chart: Sentiment Distribution
# !pip install textblob
from textblob import TextBlob

# Function to get sentiment category
def get_sentiment_category(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity == 0:
        return "Neutral"
    else:
        return "Negative"

# Apply the function to the 'review' column
merged_data["sentiment_category"] = merged_data["review"].apply(get_sentiment_category)

# Now you can proceed with creating Chart - 13
sentiment_counts = merged_data["sentiment_category"].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(
    sentiment_counts, labels=sentiment_counts.index, autopct="%1.1f%%", startangle=140,
    wedgeprops=dict(width=0.3), colors=["#66b3ff", "#99ff99", "#ffcc99"]
)
plt.title("Sentiment Distribution of Reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A donut chart (pie chart with a hole) was chosen to visualize proportions of different sentiments in reviews. It helps in quickly identifying the overall customer sentiment towards a product or service.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * 75% of the reviews are Positive, indicating strong customer satisfaction.
# * 19.8% are Negative, which is relatively low but still significant.
# * 5.2% are Neutral, meaning a small percentage of users had mixed feelings or didn’t express strong opinions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * A high percentage of positive reviews builds brand reputation and attracts new customers.Marketing campaigns can focus on highlighting positive feedback.
#
# * The 19.8% negative reviews should be analyzed for common pain points (e.g., product issues, service complaints).

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Heatmap: Correlation Matrix
plt.figure(figsize=(12, 8))
numeric_data = merged_data.select_dtypes(include=np.number)
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix of Features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * It visually represents the relationships between numerical features. Helps identify multicollinearity and feature importance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Cost & Has_Collections (0.45): Higher-cost items are often part of collections.
# * Pictures & Review Length (0.47): More images correlate with longer reviews.
# * Rating & Review Length (-0.032): No significant correlation.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(merged_data, hue="rating")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It helps visualize relationships between multiple numerical features in the dataset.
# The hue (rating) allows for an easy comparison of trends across different rating levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Cost & Review Length: Higher-cost products tend to have longer reviews, but variability is high.
# * Pictures & Rating: More pictures slightly correlate with higher ratings.
# * Has_Collections Feature: This is binary (0 or 1), showing two distinct distributions.
# * Density Distributions: Different feature distributions indicate potential clustering or trends in customer behavior.

# %% [markdown]
# ## ***5. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing
merged_data["review"] = merged_data["review"].astype(str).str.lower()

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations
import string
merged_data["review"] = merged_data["review"].replace(f"[{string.punctuation}]", "", regex=True)

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits
merged_data["review"] = merged_data["review"].replace(r"\d+", "", regex=True)

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# !pip install nltk
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove Stopwords
stop_words = set(stopwords.words("english"))
merged_data["review"] = merged_data["review"].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Rephrase Text
lemmatizer = WordNetLemmatizer()
merged_data["review"] = merged_data["review"].apply(lambda x: " ".join(lemmatizer.lemmatize(word) for word in x.split()))

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
merged_data["review_tokens"] = merged_data["review"].apply(word_tokenize)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# #### 8. Text Vectorization

# %%
# !pip install gensim

# %%
# Word2Vec Embeddings
from gensim.models import Word2Vec
model = Word2Vec(sentences=merged_data["review_tokens"], vector_size=100, window=5, min_count=2, workers=4)

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Text Vectorization Technique Used: Word2Vec
#
# Why Word2Vec?
# * Captures Context & Meaning: Unlike TF-IDF or BoW, it learns word relationships.
# * Efficient & Compact: Generates dense 100D vectors, reducing memory usage.
# * Handles Large Vocabulary: Avoids huge sparse matrices.
# * Pretrained Models Available: Can use existing embeddings for better generalization.

# %%
# Sentiment Analysis
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
merged_data["sentiment_score"] = merged_data["review"].apply(lambda x: sia.polarity_scores(str(x))["compound"])
merged_data["sentiment_category"] = merged_data["sentiment_score"].apply(lambda x: "Positive" if x > 0 else ("Negative" if x < 0 else "Neutral"))
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Sentiment Distribution Visualization
plt.figure(figsize=(10, 8))
sns.countplot(x=merged_data["sentiment_category"], palette="viridis")
plt.title("Distribution of Sentiments in Reviews")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-51-0bac22808841>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=merged_data["sentiment_category"], palette="viridis")

# %%
# Sentiment Score Distribution
plt.figure(figsize=(10, 8))
sns.histplot(merged_data["sentiment_score"], bins=30, kde=True, color="blue")
plt.title("Sentiment Score Distribution")
plt.xlabel("Sentiment Score")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 2. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
merged_data["review_length"] = merged_data["review"].apply(lambda x: len(str(x).split()))
selected_features = ["cost", "rating", "sentiment_score", "review_length", "pictures", "has_collections", "review_hour"]

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# * Domain Knowledge & Intuition – Selected features based on their relevance to sentiment and cost analysis.
# * Correlation Analysis – Ensured minimal multicollinearity by analyzing feature relationships.
# * Feature Engineering – Created review_length and review_hour for better sentiment and time-based insights.
# * Filter Methods – Considered features like sentiment_score and rating due to their direct impact on analysis.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# * cost – Affects customer perception and sentiment.
# * rating – Directly reflects user experience.
# * sentiment_score – Key indicator of review positivity/negativity.
# * review_length – Longer reviews may indicate strong opinions.
# * pictures – Visual content can influence user engagement.
# * has_collections – Indicates curated recommendations, affecting trust.
# * review_hour – Identifies time-based sentiment trends.

# %% [markdown]
# ### 3. Data Scaling

# %%
# Scaling your data

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
merged_data["review_hour"] = merged_data["time"].dt.hour
scaled_data = scaler.fit_transform(merged_data[selected_features])

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# * I used Standardization (StandardScaler) from sklearn.preprocessing
# * StandardScaler transforms data to have a mean of 0 and a standard deviation of 1, making it ideal for models sensitive to feature magnitude (e.g., SVM, KNN, Logistic Regression).

# %% [markdown]
# ## ***6. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# Clustering Using KMeans
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
kmeans = KMeans(n_clusters=4, random_state=42)
merged_data["cluster_labels"] = kmeans.fit_predict(scaled_data)
silhouette_avg = silhouette_score(scaled_data, merged_data["cluster_labels"])
print(f"Silhouette Score: {silhouette_avg:.2f}")
# Out:
# Silhouette Score: 0.26

# %%
# Visualizing Clusters
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
reduced_features = pca.fit_transform(scaled_data)
plt.figure(figsize=(10, 8))
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=merged_data["cluster_labels"], cmap="viridis", marker="o")
plt.title("Clusters Visualization After PCA")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.show()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %% [markdown]
# Model Used: K-Means Clustering
# * Applied K-Means (k=4) for restaurant clustering based on cost, rating, sentiment score, and reviews.
# * Silhouette Score: 0.26, indicating moderate clustering with some overlap.
#
# Performance & Insights
# * PCA Cluster Visualization: Shows clustering patterns but with slight overlaps.
# * Sentiment vs. Rating Clusters: Highlights grouping trends based on customer feedback.

# %%
# Scatterplot for Clusters
plt.figure(figsize=(10, 8))
sns.scatterplot(data=merged_data, x="sentiment_score", y="rating", hue="cluster_labels", palette="viridis")
plt.xlabel("Sentiment Score")
plt.ylabel("Rating")
plt.title("Restaurant Clusters based on Ratings")
plt.show()

# %% [markdown]
# ### ML Model - 2

# %%
# Clustering Using DBSCAN
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.5, min_samples=5)
merged_data["dbscan_labels"] = dbscan.fit_predict(scaled_data)
dbscan_silhouette_avg = silhouette_score(scaled_data, merged_data["dbscan_labels"])
print(f"DBSCAN Silhouette Score: {dbscan_silhouette_avg:.2f}")
# Out:
# DBSCAN Silhouette Score: -0.20

# %%
# Visualizing DBSCAN Clusters
plt.figure(figsize=(10, 8))
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=merged_data["dbscan_labels"], cmap="plasma", marker="o")
plt.title("DBSCAN Clusters Visualization After PCA")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.show()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %% [markdown]
# Model Used: DBSCAN (Density-Based Spatial Clustering of Applications with Noise)
# * Unlike K-Means, DBSCAN detects arbitrary-shaped clusters and outliers based on density.
#
# Parameters:
# * eps=0.5 (maximum neighborhood distance)
# * min_samples=5 (minimum points in a dense region)
# Performance & Insights
# * Silhouette Score: -0.20, indicating poor clustering, likely due to:
# * High dimensionality and noise in data.
# * Poor choice of eps and min_samples.
# * DBSCAN PCA Visualization: Sparse clusters with many outliers.
# * Sentiment vs. Rating Plot: Less clear separation than K-Means.

# %%
# Scatterplot for DBSCAN Clusters
plt.figure(figsize=(10, 8))
sns.scatterplot(data=merged_data, x="sentiment_score", y="rating", hue="dbscan_labels", palette="plasma")
plt.xlabel("Sentiment Score")
plt.ylabel("Rating")
plt.title("Restaurant Clusters (DBSCAN) based on Ratings")
plt.show()

# %% [markdown]
# ### ML Model - 3

# %%
# Clustering Using Agglomerative Clustering
from sklearn.cluster import AgglomerativeClustering

agg_clustering = AgglomerativeClustering(n_clusters=4)
merged_data["agg_labels"] = agg_clustering.fit_predict(scaled_data)
agg_silhouette_avg = silhouette_score(scaled_data, merged_data["agg_labels"])
print(f"Agglomerative Clustering Silhouette Score: {agg_silhouette_avg:.2f}")
# Out:
# Agglomerative Clustering Silhouette Score: 0.19

# %%
# Visualizing Agglomerative Clustering
plt.figure(figsize=(10, 8))
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=merged_data["agg_labels"], cmap="coolwarm", marker="o")
plt.title("Agglomerative Clustering Visualization After PCA")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.show()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %% [markdown]
# Model Used: Agglomerative Clustering
# * A hierarchical clustering method that recursively merges data points into clusters based on similarity.
# * Number of clusters: n_clusters=4 (predefined).
#
# Performance & Insights
# * Silhouette Score: 0.19, indicating weak clustering.
# * PCA Visualization: Clusters are visible but may overlap.
# * Sentiment vs. Rating Plot: Some differentiation, but clustering is not strong.

# %%
# Scatterplot for Agglomerative Clustering
plt.figure(figsize=(10, 8))
sns.scatterplot(data=merged_data, x="sentiment_score", y="rating", hue="agg_labels", palette="coolwarm")
plt.xlabel("Sentiment Score")
plt.ylabel("Rating")
plt.title("Restaurant Clusters (Agglomerative) based on Ratings")
plt.show()

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# * I considered the Silhouette Score to measure cluster cohesion and separation. A higher score indicates better-defined clusters, which is crucial for segmenting restaurants based on sentiment and ratings. However, we also visually analyzed PCA plots and scatterplots to ensure meaningful differentiation, as real-world business impact depends on actionable insights rather than just numerical scores.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Final Model Choice: K-Means
# * It produced the best-defined clusters, making it ideal for business decisions like customer segmentation.
# * Business Impact: Helps in identifying distinct customer groups based on sentiment scores and ratings, enabling targeted marketing strategies.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %%
# Get cluster centroids (inverse transform if scaled)
centroids = kmeans.cluster_centers_

# Specify the column names using the original selected features
centroid_df = pd.DataFrame(centroids, columns=selected_features)

# Plot heatmap of centroids
plt.figure(figsize=(12, 6))
sns.heatmap(centroid_df.T, cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
plt.title("K-Means Cluster Centroid Analysis")
plt.xlabel("Cluster")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# * High Engagement (Cluster 0) – Long reviews, many pictures, and positive sentiment.
# * Neutral Reviewers (Cluster 1) – Moderate sentiment, ratings, and cost.
# * Critical Reviewers (Cluster 2) – Low ratings, sentiment, and cost, with short reviews.
# * Moderate Reviewers (Cluster 3) – Balanced sentiment and ratings but less engaged in collections.
#
# Insights:
#
# * Target Cluster 0 for marketing.
# * Address Cluster 2 to improve their experience.
# * Engage Cluster 3 with loyalty programs.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Through this project, we successfully conducted a comprehensive analysis and clustering of Zomato restaurant data. The key steps included:
#
# 1. **Data Understanding and Cleaning**:
#    - We began by loading and merging the datasets containing restaurant metadata and reviews.
#    - The dataset was thoroughly examined for missing values, duplicates, and necessary preprocessing steps were performed to handle them effectively.
#    - Feature engineering was applied to create meaningful features such as 'Has_Collections', and missing values were filled using appropriate methods.
#
# 2. **Data Visualization**:
#    - Various visualizations were created to understand the relationships between different variables.
#    - Heatmaps, joint plots, box plots, and count plots helped us identify trends and patterns in the data.
#    - Word clouds and line plots provided insights into customer reviews and review trends over time.
#
# 3. **Textual Data Preprocessing**:
#    - Reviews were preprocessed by expanding contractions, removing punctuations, URLs, stopwords, and performing lemmatization.
#    - Tokenization and text vectorization using Word2Vec were implemented to convert text into numerical features.
#
# 4. **Sentiment Analysis**:
#    - Sentiment analysis was performed using VADER to classify reviews into positive, negative, and neutral sentiments.
#    - The distribution of sentiments was visualized to understand the overall customer sentiment towards the restaurants.
#
# 5. **Clustering**:
#    - Three clustering algorithms were applied: KMeans, DBSCAN, and Agglomerative Clustering.
#    - The clusters were visualized using PCA to reduce dimensionality and plot the clusters in a 2D space.
#    - KMeans was chosen as the final model due to its better-defined clusters and higher silhouette score.
#
# ### Key Insights:
# - **Cost vs. Rating**: Higher cost doesn't always guarantee better ratings; some expensive cuisines had low ratings.
# - **Cuisines**: North Indian and Chinese cuisines were the most popular, while certain mixed cuisines also showed high demand.
# - **Review Trends**: Review activity increased significantly over time, indicating rising customer engagement.
# - **Sentiments**: A majority of reviews were positive, suggesting high customer satisfaction. However, there were notable negative reviews that need attention.
#
# ### Business Impact:
# - **Pricing and Menu Adjustments**: The insights on cost vs. rating can help optimize pricing strategies and menu offerings to enhance customer satisfaction.
# - **Marketing and Promotions**: Targeting highly rated and popular cuisines for promotions can attract more customers.
# - **Quality Improvement**: Addressing negative reviews and improving the quality of lower-rated restaurants can enhance overall customer experience.
#
# ### Future Work:
# - **Model Deployment**: The final KMeans model can be deployed for real-time clustering and analysis of new restaurant data.
# - **Enhanced Sentiment Analysis**: Incorporating more advanced NLP techniques and pretrained models can improve sentiment analysis accuracy.
# - **Additional Features**: Including more features such as location, ambiance, and service quality can provide deeper insights into customer preferences.
#
# In conclusion, this project provided valuable insights into Zomato restaurant data, enabling data-driven decision-making for enhancing customer satisfaction and business growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
